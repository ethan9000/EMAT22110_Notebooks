# %%
import requests
import urllib
import json
import pandas as pd

# %%
tokens = pd.read_csv('/Users/ethanhancock/Documents/Twitter-Keys.txt', sep = '\t', header = None).T
tokens.columns = tokens.iloc[0]
tokens = tokens[1:]
#tokens.Bearer_Token[1]

# %%
def auth():
    return tokens.Bearer_Token[1]

# %%
def create_url():
    query = urllib.parse.quote('(vaccine) OR #vaccine OR #COVID #vaccine OR (COVID-19 vaccine) OR vaccines OR #vaccines OR (COVID-19 vaccines) OR (COVID vaccine) OR (COVID vaccines) -is:retweet')
    tweet_fields = 'tweet.fields=author_id,geo,lang,text,id'
    url = 'https://api.twitter.com/2/tweets/search/recent?query={}&{}'.format(query, tweet_fields)
    return url

print(create_url())
# Out:
# https://api.twitter.com/2/tweets/search/recent?query=%28vaccine%29%20OR%20%23vaccine%20OR%20%23COVID%20%23vaccine%20OR%20%28COVID-19%20vaccine%29%20OR%20vaccines%20OR%20%23vaccines%20OR%20%28COVID-19%20vaccines%29%20OR%20%28COVID%20vaccine%29%20OR%20%28COVID%20vaccines%29%20-is%3Aretweet&tweet.fields=author_id,geo,lang,text,id

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

#print(create_headers(tokens.Bearer_Token[1]))

# %%
def connect_to_endpoint(url, headers):
    response = requests.request("GET", url, headers=headers)
    print(response.status_code)
    if response.status_code !=200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def one_request():
    bearer_token = auth()
    url = create_url()
    headers = create_headers(bearer_token)
    json_response = connect_to_endpoint(url, headers)
    return json_response

# %%
results = one_request()
# Out:
# 200

# %%
results.keys()
# Out:
# dict_keys(['data', 'meta'])

# %%
tweet_dat = pd.DataFrame(results['data'])

# %%
tweet_dat
# Out:
#                     id                                               text  \
# 0  1386889635545055235  RT @IndiaToday: #AstraZeneca said in response ...
# 1  1386889634945306626  RT @arunbothra: After vaccination a person can...
# 2  1386889634274189319  @ZeeNewsEnglish Then they must announce the ra...
# 3  1386889633850707968  @_Oliver_Yates @normanswan @Ama I can hear you...
# 4  1386889633598947329  RT @DeFede: BREAKING: A private school in Miam...
# 5  1386889633271791617  RT @scdp: You're invited to a conversation wit...
# 6  1386889632214704128  RT @MarcusReports: I've been MIA from Twitter ...
# 7  1386889631849869316  RT @HTSmartcast: Will vaccines be free or paid...
# 8  1386889631761846275  RT @TorontoFarmEN: With more and more clearer ...
# 9  1386889631292141568  RT @windthin: This might be the single stupide...
#
#   lang            author_id
# 0   en  1234011788401725440
# 1   en           1282508052
# 2   en           2320195988
# 3   en           2926204339
# 4   en             32876422
# 5   en   997226312539557890
# 6   en           3193226809
# 7   en  1203504066250149893
# 8   en  1320856580687122432
# 9   en  1311075491160485890

# %% [markdown]
# ### To collect the data I used the Twitter API to collect tweets that included key words that would suggest they are associated with the COVID-19 vaccine.

# %%
def create_url_pag(next_token = None):
    if (next_token):
        query = urllib.parse.quote('(vaccine) OR #vaccine OR #COVID #vaccine OR (COVID-19 vaccine) OR vaccines OR #vaccines OR (COVID-19 vaccines) OR (COVID vaccine) OR (COVID vaccines) -is:retweet')
        tweet_fields = 'tweet.fields=author_id,geo,lang,text,id'
        pagination = str(next_token)
        url = 'https://api.twitter.com/2/tweets/search/recent?query={}&next_token={}&{}'.format(query, pagination, tweet_fields)
        return url
    else:
        query = urllib.parse.quote('(vaccine) OR #vaccine OR #COVID #vaccine OR (COVID-19 vaccine) OR vaccines OR #vaccines OR (COVID-19 vaccines) OR (COVID vaccine) OR (COVID vaccines) -is:retweet')
        tweet_fields = 'tweet.fields=author_id,geo,lang,text,id'
        url = 'https://api.twitter.com/2/tweets/search/recent?query={}&{}'.format(query, tweet_fields)
        return url
print(create_url_pag(None))
print(create_url_pag('000000000000000'))
# Out:
# https://api.twitter.com/2/tweets/search/recent?query=%28vaccine%29%20OR%20%23vaccine%20OR%20%23COVID%20%23vaccine%20OR%20%28COVID-19%20vaccine%29%20OR%20vaccines%20OR%20%23vaccines%20OR%20%28COVID-19%20vaccines%29%20OR%20%28COVID%20vaccine%29%20OR%20%28COVID%20vaccines%29%20-is%3Aretweet&tweet.fields=author_id,geo,lang,text,id
# https://api.twitter.com/2/tweets/search/recent?query=%28vaccine%29%20OR%20%23vaccine%20OR%20%23COVID%20%23vaccine%20OR%20%28COVID-19%20vaccine%29%20OR%20vaccines%20OR%20%23vaccines%20OR%20%28COVID-19%20vaccines%29%20OR%20%28COVID%20vaccine%29%20OR%20%28COVID%20vaccines%29%20-is%3Aretweet&next_token=000000000000000&tweet.fields=author_id,geo,lang,text,id

# %%
def pages():
    count = 0
    next_token = None
    dat = pd.DataFrame()
    while (count < 450):
        bearer_token = auth()
        url = create_url_pag(next_token)
        headers = create_headers(bearer_token)
        json_response = connect_to_endpoint(url, headers)
        next_token = json_response['meta']['next_token']
        dat = dat.append(pd.DataFrame(json_response['data']))
        count = count + 1
    return dat

# %%
pages = pages()
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len(pages.id)
# Out:
# 4499

# %% [markdown]
# I collected 4499 tweets. Each tweet has an author id which identifies the author of the tweet, the id which is the tweet's individual identifier, the text that is the actual tweet, the lang which is the language the tweet is written in, and the geo which is a location mentioned in the tweet.

# %%
pages.head(40)
# Out:
#              author_id                   id  \
# 0           3004002340  1386894744391979016
# 1            105624082  1386894744006049792
# 2             25054096  1386894743582306304
# 3            370483806  1386894743448166400
# 4  1285971559665094656  1386894742542245892
# 5  1320781853679255552  1386894742416330754
# 6           1416169716  1386894742173233152
# 7  1343980366764208128  1386894741279711232
# 8             15797509  1386894740910755842
# 9           1146566496  1386894740889772032
# 0           2894280834  1386894740306628609
# 1            733494205  1386894739992195077
# 2           2813719364  1386894739606224896
# 3            182307108  1386894739564240899
# 4  1348470524834320384  1386894739073503232
# 5  1269985279529664514  1386894738704510979
# 6            134455056  1386894738565996546
# 7  1278900675796021248  1386894737626464258
# 8            468705778  1386894735973834753
# 9           1035919266  1386894735244206087
# 0           2855536108  1386894734061363202
# 1            106181720  1386894732358422537
# 2             90850685  1386894730810724352
# 3   988517362436460544  1386894729598492674
# 4  1321803071173746689  1386894728788996107
# 5           1619325942  1386894727350394884
# 6   709936443410374656  1386894727283449858
# 7           1416169716  1386894726373195780
# 8              9164492  1386894725274226694
# 9            169375114  1386894724842151938
# 0           1078949226  1386894723906895875
# 1  1293750568029057026  1386894722363318276
# 2            143765429  1386894721331597314
# 3  1371758884688261126  1386894719549001728
# 4             68950503  1386894719150665732
# 5  1069714472544157696  1386894718697619456
# 6             25645444  1386894718634655747
# 7  1292324727952797700  1386894718357807105
# 8            149277660  1386894717892403206
# 9  1156581287316119552  1386894717821100034
#
#                                                 text lang  \
# 0  @Marc_Perrone The Pfizer and Moderna shots are...   en
# 1  RT @ShayRokkzPink: Me watchin ya'll from outsi...   en
# 2  RT @POTUS: Remember: If you received either th...   en
# 3  RT @meinmokhtar: Soalan: astrazeneca vaccine n...   in
# 4  @audreydeleonn yeah it’s probably the vaccine ...   en
# 5  RT @ratemyskyperoom: Room Rater Canada Gets Va...   en
# 6  RT @HighWireTalk: More than 5 million people, ...   en
# 7  RT @narendramodi: My discussion with @POTUS @J...   en
# 8                            https://t.co/kqg0DuKTCq  und
# 9  RT @HighWireTalk: More than 5 million people, ...   en
# 0  RT @afroelven: NY recently passed a law that r...   en
# 1  RT @JeanmarcBenoit: VAERS covid vaccine report...   en
# 2  RT @JRehling: Antimaskers and antivaxxers woul...   en
# 3  RT @DrAvnii: 1st batch of Sputnik V vaccine to...   en
# 4  @DeeEllDee @globalnews @liberal_party Canada c...   en
# 5  RT @itswalela: artists touring live, festivals...   en
# 6  RT @chr1sa: It's now been almost a year since ...   en
# 7  India records over 3.23 lakh fresh cases, 2,77...   en
# 8        Which vaccine where https://t.co/SCo6Dha2sZ   en
# 9  RT @Polo1De: There's a growing trend of people...   en
# 0  RT @CrownSlew: Anyone surprised? Every day ano...   en
# 1  RT @ShayRokkzPink: Me watchin ya'll from outsi...   en
# 2  RT @ReutersJapan: ワクチン接種加速へ東京に大規模センター、5月24日から3...   ja
# 3  RT @jogalshailaja: महाराष्ट्राची विक्रमी कामगि...   mr
# 4  RT @TheQuint: "Govt knew vaccines were the key...   en
# 5  West Virginia will give US$100 savings bond to...   en
# 6  RT @arlenparsa: A typical flu shot is only 40-...   en
# 7  RT @NVICLoeDown: Facebook deletes 120,000-memb...   en
# 8         How_To_Not_Randomly_Get_The_AZ_Vaccine.pdf   en
# 9  RT @idlewild_: In the midst of yelling at vacc...   en
# 0  RT @jenneraub: @SMooreesq The idea of a "vacci...   en
# 1  RT @h_okumura: 昨日までの接種実績 https://t.co/051WGln3...   ja
# 2  RT @WSJ: “I’m beginning to see a slow movement...   en
# 3  RT @FrontalForce: 1st batch of Sputnik V vacci...   en
# 4  RT @POTUS: Remember: If you received either th...   en
# 5  RT @afroelven: NY recently passed a law that r...   en
# 6  RT @jesus_jimz: This is like buying half of a ...   en
# 7  RT @RMantri: If true, there will for sure be a...   en
# 8  RT @SocialistVoice: The global battle over dru...   en
# 9  @colbertlateshow \nTo the staff person reading...   en
#
#                                 geo withheld
# 0                               NaN      NaN
# 1                               NaN      NaN
# 2                               NaN      NaN
# 3                               NaN      NaN
# 4                               NaN      NaN
# 5                               NaN      NaN
# 6                               NaN      NaN
# 7                               NaN      NaN
# 8                               NaN      NaN
# 9                               NaN      NaN
# 0                               NaN      NaN
# 1                               NaN      NaN
# 2                               NaN      NaN
# 3                               NaN      NaN
# 4                               NaN      NaN
# 5                               NaN      NaN
# 6                               NaN      NaN
# 7  {'place_id': '2c614b2aca285e79'}      NaN
# 8  {'place_id': '7929cea6bd5b32bd'}      NaN
# 9                               NaN      NaN
# 0                               NaN      NaN
# 1                               NaN      NaN
# 2                               NaN      NaN
# 3                               NaN      NaN
# 4                               NaN      NaN
# 5                               NaN      NaN
# 6                               NaN      NaN
# 7                               NaN      NaN
# 8                               NaN      NaN
# 9                               NaN      NaN
# 0                               NaN      NaN
# 1                               NaN      NaN
# 2                               NaN      NaN
# 3                               NaN      NaN
# 4                               NaN      NaN
# 5                               NaN      NaN
# 6                               NaN      NaN
# 7                               NaN      NaN
# 8                               NaN      NaN
# 9                               NaN      NaN
