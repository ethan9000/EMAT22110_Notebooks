# %%
import pandas as pd

# %%
oly_uniq = pd.read_csv('/Volumes/Drive2/EMAT22110_Notebooks/InClass/Olympics_Postponed_Twitter_Unique.csv')
oly_uniq.keys()
# Out:
# Index(['Date', 'Title', 'Url', 'Language', 'Author', 'Avatar',
#        'Category Details', 'Checked', 'City', 'Display URLs', 'Expanded URLs',
#        'Full Name', 'Full Text', 'Gender', 'Hashtags', 'Impact', 'Impressions',
#        'Latitude', 'Location Name', 'Longitude', 'Media Filter', 'Media URLs',
#        'Mentioned Authors', 'Original Url', 'Thread Author',
#        'Thread Created Date', 'Thread Entry Type', 'Thread Id', 'Thread URL',
#        'Twitter Author ID', 'Twitter Channel Role', 'Twitter Followers',
#        'Twitter Following', 'Twitter Reply Count', 'Twitter Reply to',
#        'Twitter Retweet of', 'Twitter Retweets', 'Twitter Tweets',
#        'Twitter Verified', 'Updated', 'Reach (new)'],
#       dtype='object')

# %%
en_only = oly_uniq.loc[oly_uniq['Language'] == 'en']
en_only
# Out:
#                         Date  \
# 0      2020-03-31 23:58:48.0
# 1      2020-03-31 23:57:17.0
# 2      2020-03-31 23:57:00.0
# 3      2020-03-31 23:56:25.0
# 4      2020-03-31 23:55:31.0
# ...                      ...
# 19709  2020-03-22 00:02:31.0
# 19710  2020-03-22 00:02:11.0
# 19711  2020-03-22 00:01:41.0
# 19712  2020-03-22 00:01:17.0
# 19713  2020-03-22 00:00:32.0
#
#                                                    Title  \
# 0      @TeamUSA Literally all of the 2012 Olympics fo...
# 1      @LanderVBALL @reesebatesvb @vbcoch @USAVBeach ...
# 2      "To be blunt, it started women's basketball in...
# 3      @DetroitHandball @TeamHandball @USATH @USARugb...
# 4      I beat my own record! The new one is 52!!! @US...
# ...                                                  ...
# 19709  Wrestling is on!!! Thanks @USAWrestling for th...
# 19710  @mitchell_ness @usabasketball Hell yes! I’d bu...
# 19711  @nelses1 @PLBpalhal_ @MilenaUjkicWick @Noah_Ha...
# ...

# %%
en_only['Full Text'].head()
# Out:
# 0    @TeamUSA Literally all of the 2012 Olympics fo...
# 1    @LanderVBALL @reesebatesvb @vbcoch @USAVBeach ...
# 2    "To be blunt, it started women's basketball in...
# 3    @DetroitHandball @TeamHandball @USATH @USARugb...
# 4    I beat my own record! The new one is 52!!! @US...
# Name: Full Text, dtype: object

# %%
en_only['text_lower'] = [x.lower() for x in en_only['Full Text']]
en_only['text_lower'].head(20)
# Out:
# <ipython-input-10-37a9bf0ef53a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_only['text_lower'] = [x.lower() for x in en_only['Full Text']]
# 0     @teamusa literally all of the 2012 olympics fo...
# 1     @landervball @reesebatesvb @vbcoch @usavbeach ...
# 2     "to be blunt, it started women's basketball in...
# 3     @detroithandball @teamhandball @usath @usarugb...
# 4     i beat my own record! the new one is 52!!! @us...
# 5     @detroithandball @teamhandball @usath @usarugb...
# 6     @glamourmag @alexmorgan13 @uswnt @samanthabarr...
# 7      @teamusa miracle on ice! https://t.co/ybhm1dvjaj
# 9        @teamusa the four horse chariot race of 680 bc
# 10    @firstladyofchem @uswnt @abbywambach @carlillo...
# ...

# %%
import nltk
from nltk import tokenize as tk
from nltk import FreqDist
import pandas as pd
from nltk.corpus import stopwords
#import matplotlib
import string
#nltk.download('punkt')

# %%
en_only['tokens'] = [tk.word_tokenize(x) for x in en_only['text_lower']]
en_only['tokens'][0]
# Out:
# <ipython-input-12-044f11eba0b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_only['tokens'] = [tk.word_tokenize(x) for x in en_only['text_lower']]
# ['@',
#  'teamusa',
#  'literally',
#  'all',
#  'of',
#  'the',
#  '2012',
#  'olympics',
#  'for',
#  'women',
#  "'s",
#  'artistic',
#  'gymnastics']

# %%
#nltk.download('stopwords')
mystopwords = stopwords.words('english')
mystopwords.append("n't")
mystopwords.append("'s")

# %%
filtered = []
for i in en_only['tokens']:
    filtered.append([word for word in i if word not in mystopwords])
    
en_only['filtered'] = filtered
# Out:
# <ipython-input-17-2c9d947a60aa>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_only['filtered'] = filtered

# %% [markdown]
# en_only['filtered'][2]
